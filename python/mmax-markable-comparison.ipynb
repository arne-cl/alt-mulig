# %% [markdown]
# # Q: Are there NPs/PPs in PCC that aren't markables although they should be?

# %%
import os
import glob

import discoursegraphs as dg

# %%
MMAX_ROOT_DIR = os.path.expanduser('/home/arne/corpora/potsdam-commentary-corpus-2.0.0/coreference/')
TIGER_ROOT_DIR = os.path.expanduser('/home/arne/corpora/potsdam-commentary-corpus-2.0.0/syntax/')


MMAX_TEST_FILE = os.path.join(MMAX_ROOT_DIR, 'maz-1423.mmax')
TIGER_TEST_FILE = os.path.join(TIGER_ROOT_DIR, 'maz-1423.xml')

# %%
for mmax_file in glob.glob(MMAX_ROOT_DIR+'*.mmax'):
    dg.read_mmax2(mmax_file)

# %%
mdg = dg.read_mmax2(MMAX_TEST_FILE)
tdg = dg.read_tiger(TIGER_TEST_FILE)
mdg.merge_graphs(tdg)

# %%
dg.info(mdg)
# Out:
# Name: maz-1423.mmax
# Type: MMAXDocumentGraph
# Number of nodes: 325
# Number of edges: 358
# Average in degree:   1.1015
# Average out degree:   1.1015
#
# Node statistics
# ===============
#
# number of nodes with layers
# 	tiger - 286
# 	mmax - 207
# 	tiger:token - 185
# 	mmax:token - 185
# 	tiger:syntax - 68
# 	tiger:sentence - 32
# 	mmax:markable - 21
# 	mmax:primmark - 21
# 	tiger:sentence:vroot - 16
# 	mmax:sentence - 16
# 	tiger:sentence:root - 16
# 	discoursegraph - 1
#
# number of nodes with attributes
# 	layers - 325
# 	label - 290
# 	tiger:id - 285
# 	tiger:word - 185
# 	tiger:morph - 185
# 	tiger:token - 185
# 	tiger:lemma - 185
# 	tiger:pos - 185
# 	mmax:token - 185
# 	tiger:cat - 84
# 	tokens - 32
# 	mmax:ambiguity - 21
# 	mmax:np_form - 21
# 	mmax:phrase_type - 21
# 	mmax:referentiality - 21
# 	mmax:id - 21
# 	mmax:grammatical_role - 21
# 	mmax:dir_speech - 21
# 	mmax:type - 21
# 	mmax:anaphor_antecedent - 21
# 	mmax:complex_np - 21
# 	mmax:span - 21
# 	tiger:orig_id - 16
# 	tiger:art_id - 16
# 	mmax:anaphor_type - 9
# 	metadata - 1
#
# Edge statistics
# ===============
#
# number of edges with layers
# 	tiger - 301
# 	tiger:edge - 231
# 	tiger:sentence - 70
# 	mmax - 57
# 	mmax:markable - 57
# 	mmax:primmark - 57
# 	tiger:unconnected - 38
# 	tiger:sentence:vroot - 16
#
# number of edges with attributes
# 	layers - 358
# 	edge_type - 358
# 	label - 288
# 	tiger:idref - 231
# 	tiger:label - 231
#
# most common source edges
# 	tiger:root_node - 16
# 	markable_16 - 6
# 	VROOT-s525 - 5
# 	markable_7 - 5
# 	s538_505 - 5
#
# most common target edges
# 	discoursegraph:root_node - 16
# 	word_10 - 3
# 	word_149 - 2
# 	word_140 - 2
# 	word_141 - 2

# %%
def extract_potential_markables(docgraph):
    potential_markables = {}
    
    for node_id, nattr in dg.select_nodes_by_layer(docgraph, 'tiger:syntax', data=True):
        if nattr['tiger:cat'] == 'NP':
            # if an NP is embedded into a PP, only print the PP
            pp_parent = False
            for source, target in docgraph.in_edges(node_id):
                parent_node = docgraph.node[source]
                if 'tiger:cat' in parent_node and parent_node['tiger:cat'] == 'PP':
                    potential_markables[source] = (parent_node['tiger:cat'], dg.get_span(docgraph, source))
                    pp_parent = True
            if not pp_parent:
                potential_markables[node_id] = (nattr['tiger:cat'], dg.get_span(docgraph, node_id))
                
        elif nattr['tiger:cat'] == 'PP':
            potential_markables[node_id] = (nattr['tiger:cat'], dg.get_span(docgraph, node_id))
    return potential_markables

# %%
all_potential_markables = {}
for mmax_file in glob.glob(MMAX_ROOT_DIR+'*.mmax')[:10]:
    doc_id = os.path.basename(mmax_file).split('.')[0]
    mdg = dg.read_mmax2(mmax_file)
    tdg = dg.read_tiger(os.path.join(TIGER_ROOT_DIR, doc_id+'.xml'))
    mdg.merge_graphs(tdg)
    all_potential_markables[mdg] = extract_potential_markables(mdg)

# %%
mdg, potential_markables = all_potential_markables.items()[0]

# %%
for cat_node in potential_markables:
    cat, token_ids = potential_markables[cat_node]
    for token_id in token_ids:
        in_edges = mdg.in_edges(token_id, data=True)
        for source, target, eattr in in_edges:
            print source, eattr, '\n'
# Out:
# s1507_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_15', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_16', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_17', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_18', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_19', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# s1507_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_17', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_18', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_19', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# s1507_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_8', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_9', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_10', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# s1507_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1508_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_11', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# s1508_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_12', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1507_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_22', 'edge_type': 'spans', 'tiger:label': 'MO', 'label': 'MO'}
#
# markable_55 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_23', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_55 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_24', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_15', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_23 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_17', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_23 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_18', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_23 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_19', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_23 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_20', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_23 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_21', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1503_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1503_3', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# s1503_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1503_4', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1503_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1503_5', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_10', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_15', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_6', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_7', 'edge_type': 'spans', 'tiger:label': 'MO', 'label': 'MO'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_8', 'edge_type': 'spans', 'tiger:label': 'HD', 'label': 'HD'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_9', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_10', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_15', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1502_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1502_15', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_27 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_26 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_25 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_509 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_15', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_509 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_16', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_18', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_19', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_20', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_21', 'edge_type': 'spans', 'tiger:label': 'CM', 'label': 'CM'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_22', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_23', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_1000175 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_24', 'edge_type': 'spans', 'tiger:label': 'PM', 'label': 'PM'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_25', 'edge_type': 'spans', 'tiger:label': 'HD', 'label': 'HD'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_27', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_11 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_28', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_11 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_18', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1501_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_19', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1501_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_13', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# s1501_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1504_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# s1504_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# s1504_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_7', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# s1504_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_8', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1504_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_9', 'edge_type': 'spans', 'tiger:label': 'MO', 'label': 'MO'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1504_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_10', 'edge_type': 'spans', 'tiger:label': 'HD', 'label': 'HD'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# s1504_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1500_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1500_3', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1500_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1500_4', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1500_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1500_5', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1501_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1501_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_12', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_6 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_8', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_6 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_9', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1501_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_10', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_6 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_100016 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1504_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_5', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1504_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_6', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# s1504_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_7', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# s1504_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_8', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1504_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_9', 'edge_type': 'spans', 'tiger:label': 'MO', 'label': 'MO'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1504_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_10', 'edge_type': 'spans', 'tiger:label': 'HD', 'label': 'HD'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000178 {'layers': set(['mmax', 'mmax:markable', 'mmax:secmark']), 'edge_type': 'spans', 'label': 'mmax:secmark'}
#
# s1504_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1504_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_37 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_18', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_19', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_20', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_21', 'edge_type': 'spans', 'tiger:label': 'CM', 'label': 'CM'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_22', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_23', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_1000175 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_75 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_10', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_75 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_12 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_29', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_12 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_100036 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_30', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_21', 'edge_type': 'spans', 'tiger:label': 'CM', 'label': 'CM'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_22', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1509_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1509_23', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_1000175 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_83 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1508_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_4', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# s1508_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_5', 'edge_type': 'spans', 'tiger:label': 'MO', 'label': 'MO'}
#
# s1508_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_6', 'edge_type': 'spans', 'tiger:label': 'HD', 'label': 'HD'}
#
# s1508_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_10 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_20', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_10 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_21', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_10 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_22', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_10 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_23', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1507_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_15', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_16', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_17', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_18', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_19', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# s1507_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_1', 'edge_type': 'spans', 'tiger:label': 'NG', 'label': 'NG'}
#
# s1507_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_2', 'edge_type': 'spans', 'tiger:label': 'HD', 'label': 'HD'}
#
# s1507_510 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_3', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_510 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_4', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_510 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_5', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_509 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1507_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_8', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_9', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_10', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# s1507_505 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_11', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_508 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_14', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1507_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_15', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_507 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_16', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_506 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_17', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_18', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_62 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1507_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_19', 'edge_type': 'spans', 'tiger:label': 'NMC', 'label': 'NMC'}
#
# markable_13 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_509 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_1', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_13 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_509 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_2', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_13 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_3', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_13 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_4', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1505_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1505_5', 'edge_type': 'spans', 'tiger:label': 'MO', 'label': 'MO'}
#
# markable_42 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1505_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1505_6', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_42 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000176 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1505_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1505_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_42 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000176 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1505_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1505_8', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_42 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_1000176 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1505_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1505_9', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_42 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_6', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_5 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1501_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1501_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_5 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_66 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1508_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_1', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_66 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1508_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1508_2', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_1', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_2', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_3', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_4', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_5', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_6', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1507_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_27', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1507_504 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1507_28', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1506_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_12', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# s1506_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_13', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# s1506_502 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_14', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_3', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_503 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_4', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_5', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_6', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_5', 'edge_type': 'spans', 'tiger:label': 'AC', 'label': 'AC'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_6', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_48 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_44 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# markable_47 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_500 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_7', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_45 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_9', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}
#
# markable_45 {'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'edge_type': 'spans', 'label': 'mmax:primmark'}
#
# s1506_501 {'layers': set(['tiger', 'tiger:edge']), 'tiger:idref': 's1506_10', 'edge_type': 'spans', 'tiger:label': 'NK', 'label': 'NK'}

# %%
# real markables

mdg = dg.read_mmax2(MMAX_TEST_FILE)
for markable, mattr in dg.select_nodes_by_layer(mdg, 'mmax:markable', data=True):
    print markable, mattr, '\n'
# Out:
# markable_18 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'ne', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_18', 'mmax:grammatical_role': 'indir-obj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_18:primmark', 'mmax:span': 'word_152', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_19 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'ne', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'anaphoric', 'mmax:id': 'markable_19', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_19:primmark', 'mmax:span': 'word_160..word_161', 'mmax:anaphor_antecedent': 'markable_17', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_13 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_13', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_13:primmark', 'mmax:span': 'word_109..word_110', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_10 {'layers': set(['mmax', 'mmax:primmark', 'mmax:markable']), 'mmax:dir_speech': 'text_level', 'mmax:type': 'anaphoric', 'mmax:id': 'markable_10', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'sbj', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_10:primmark', 'mmax:span': 'word_94..word_95', 'mmax:anaphor_antecedent': 'markable_8', 'mmax:phrase_type': 'np', 'mmax:np_form': 'defnp', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_11 {'layers': set(['mmax', 'mmax:primmark', 'mmax:markable']), 'mmax:dir_speech': 'text_level', 'mmax:type': 'none', 'mmax:id': 'markable_11', 'mmax:grammatical_role': 'other', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_11:primmark', 'mmax:span': 'word_10', 'mmax:anaphor_antecedent': 'empty', 'mmax:phrase_type': 'np', 'mmax:np_form': 'ne', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_16 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_16', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_16:primmark', 'mmax:span': 'word_136..word_141', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'yes'}
#
# markable_17 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'ne', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'anaphoric', 'mmax:id': 'markable_17', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'indir-obj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_17:primmark', 'mmax:span': 'word_149', 'mmax:anaphor_antecedent': 'markable_14', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_14 {'layers': set(['mmax', 'mmax:primmark', 'mmax:markable']), 'mmax:dir_speech': 'text_level', 'mmax:type': 'anaphoric', 'mmax:id': 'markable_14', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'sbj', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_14:primmark', 'mmax:span': 'word_116', 'mmax:anaphor_antecedent': 'markable_12', 'mmax:phrase_type': 'np', 'mmax:np_form': 'ne', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_15 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'ne', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_15', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_15:primmark', 'mmax:span': 'word_125..word_126', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_12 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'anaphoric', 'mmax:id': 'markable_12', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'other', 'mmax:phrase_type': 'pp', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_12:primmark', 'mmax:span': 'word_101..word_103', 'mmax:anaphor_antecedent': 'markable_11', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_1 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_1', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_1:primmark', 'mmax:span': 'word_3..word_4', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_2 {'layers': set(['mmax', 'mmax:primmark', 'mmax:markable']), 'mmax:dir_speech': 'text_level', 'mmax:type': 'none', 'mmax:id': 'markable_2', 'mmax:grammatical_role': 'sbj', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_2:primmark', 'mmax:span': 'word_8..word_11', 'mmax:anaphor_antecedent': 'empty', 'mmax:phrase_type': 'np', 'mmax:np_form': 'defnp', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_3 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_3', 'mmax:grammatical_role': 'indir-obj', 'mmax:phrase_type': 'pp', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_3:primmark', 'mmax:span': 'word_25..word_28', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_4 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_4', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_4:primmark', 'mmax:span': 'word_30..word_31', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_5 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_5', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_5:primmark', 'mmax:span': 'word_46..word_47', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_6 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_6', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_6:primmark', 'mmax:span': 'word_58..word_59', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_7 {'layers': set(['mmax', 'mmax:primmark', 'mmax:markable']), 'mmax:dir_speech': 'text_level', 'mmax:type': 'anaphoric', 'mmax:id': 'markable_7', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'other', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_7:primmark', 'mmax:span': 'word_60..word_63', 'mmax:anaphor_antecedent': 'markable_2', 'mmax:phrase_type': 'pp', 'mmax:np_form': 'defnp', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_8 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'anaphoric', 'mmax:id': 'markable_8', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'dir-obj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_8:primmark', 'mmax:span': 'word_73..word_74', 'mmax:anaphor_antecedent': 'markable_7', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_9 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'none', 'mmax:id': 'markable_9', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_9:primmark', 'mmax:span': 'word_90..word_91', 'mmax:anaphor_antecedent': 'empty', 'mmax:referentiality': 'discourse-new', 'mmax:complex_np': 'no'}
#
# markable_22 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'ne', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'anaphoric', 'mmax:id': 'markable_22', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'sbj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_22:primmark', 'mmax:span': 'word_180', 'mmax:anaphor_antecedent': 'markable_19', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}
#
# markable_21 {'mmax:dir_speech': 'text_level', 'mmax:np_form': 'defnp', 'layers': set(['mmax', 'mmax:markable', 'mmax:primmark']), 'mmax:type': 'anaphoric', 'mmax:id': 'markable_21', 'mmax:anaphor_type': 'anaphor_nominal', 'mmax:grammatical_role': 'dir-obj', 'mmax:phrase_type': 'np', 'mmax:ambiguity': 'not_ambig', 'label': 'markable_21:primmark', 'mmax:span': 'word_177..word_178', 'mmax:anaphor_antecedent': 'markable_10', 'mmax:referentiality': 'referring', 'mmax:complex_np': 'no'}

# %%
mdg.in_edges('s531_501')
# Out:
# [('s531_507', 's531_501')]
