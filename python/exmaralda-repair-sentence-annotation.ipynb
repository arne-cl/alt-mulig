# %% [markdown]
# # Task: add missing sentence-level annotations to Exmaralda files

# %% [markdown]
# AP told me that 20 of the Exmaralda-annotated MAZ176 files don't have a `tiger:sentence` tier.
#
# ```
# $ for i in *.exb ; do grep -cH "category=\"sentence\"" $i ; done | grep "0$"
# maz-00001.exb:0
# maz-00002.exb:0
# maz-1423.exb:0
# maz-1453.exb:0
# maz-1679.exb:0
# maz-1757.exb:0
# maz-1818.exb:0
# maz-2316.exb:0
# maz-2609.exb:0
# maz-2611.exb:0
# maz-2669.exb:0
# maz-3073.exb:0
# maz-3080.exb:0
# maz-3110.exb:0
# maz-3277.exb:0
# maz-3367.exb:0
# maz-3377.exb:0
# maz-3415.exb:0
# maz-3547.exb:0
# maz-4031.exb:0
# ```
#
# The annotations mentioned are present in the Exmaralda files I gave to the annotator:
#
# ```
# $ /tmp/pcc176_tiger2exmaralda $ ack-grep -c "category=\"sentence\"" | cut -d : -f 2 | uniq
# 1
# ```

# %%
import os
import glob

BROKEN_EXMARALDA_DIR = os.path.expanduser('~/repos/pcc-annis-merged/maz176/information-structure/')

# %%
exmaralda_files = glob.glob(os.path.join(BROKEN_EXMARALDA_DIR, '*.exb'))

# %%
EXB_EXAMPLE = exmaralda_files[0]
print EXB_EXAMPLE
# Out:
# /home/arne/repos/pcc-annis-merged/maz176/information-structure/maz-14813.exb

# %%
from lxml import etree

# %%
tree = etree.parse(EXB_EXAMPLE)

# %%
ct = tree.find('//common-timeline')

# %%
from operator import itemgetter

tokenid_time_tuples = sorted( [(tli.attrib['id'], float(tli.attrib['time'])) for tli in ct.iterchildren()], key=itemgetter(1))

# %%
for tier in tree.iter('tier'):
    print tier.attrib['id'], tier.attrib['category'], tier.attrib['type'], tier.attrib['display-name']
    for event in tier.iter('event'):
        print '\t', event.attrib['start'], event.attrib['end'], event.text
# Out:
# TIE0 tok t [tok]
# 	T0 T1 Knebelvertrag
# 	T1 T2 Eigentlich
# 	T2 T3 können
# 	T3 T4 wir
# 	T4 T5 es
# 	T5 T6 nicht
# 	T6 T7 mehr
# 	T7 T8 sehen
# 	T8 T9 :
# 	T9 T10 Harry-Potter-Tassen
# 	T10 T11 ,
# 	T11 T12 Potter
# 	T12 T13 T-Shirts
# 	T13 T14 ,
# 	T14 T15 kleine
# 	T15 T16 Potter-Legomännchen
# 	T16 T17 und
# 	T17 T18 so
# 	T18 T19 weiter
# 	T19 T20 .
# 	T20 T21 Und
# 	T21 T22 nun
# 	T22 T23 folgt
# 	T23 T24 gleich
# 	T24 T25 das
# 	T25 T26 zweite
# 	T26 T27 Mega-Kinoereignis
# 	T27 T28 :
# 	T28 T29 "
# 	T29 T30 Der
# 	T30 T31 Herr
# 	T31 T32 der
# 	T32 T33 Ringe
# 	T33 T34 "
# 	T34 T35 .
# 	T35 T36 Bereits
# 	T36 T37 in
# 	T37 T38 jedem
# 	T38 T39 siebten
# 	T39 T40 Kinderüberraschungsei
# 	T40 T41 findet
# 	T41 T42 sich
# 	T42 T43 ein
# 	T43 T44 Frodo
# 	T44 T45 oder
# 	T45 T46 eine
# 	T46 T47 Elbenkönigin
# 	T47 T48 .
# 	T48 T49 Da
# 	T49 T50 boomt
# 	T50 T51 die
# 	T51 T52 Industrie
# 	T52 T53 gewaltig
# 	T53 T54 ,
# 	T54 T55 mag
# 	T55 T56 man
# 	T56 T57 so
# 	T57 T58 denken
# 	T58 T59 und
# 	T59 T60 die
# 	T60 T61 gebeutelten
# 	T61 T62 Kinos
# 	T62 T63 bekommen
# 	T63 T64 auch
# 	T64 T65 noch
# 	T65 T66 einen
# 	T66 T67 dicken
# 	T67 T68 Batzen
# 	T68 T69 ab
# 	T69 T70 .
# 	T70 T71 Aber
# 	T71 T72 was
# 	T72 T73 macht
# 	T73 T74 ein
# 	T74 T75 Lichtspieltheaterchef
# 	T75 T76 in
# 	T76 T77 der
# 	T77 T78 Provinz
# 	T78 T79 ,
# 	T79 T80 der
# 	T80 T81 erst
# 	T81 T82 abends
# 	T82 T83 seine
# 	T83 T84 Pforten
# 	T84 T85 öffnen
# 	T85 T86 kann
# 	T86 T87 ?
# 	T87 T88 Um
# 	T88 T89 Harry
# 	T89 T90 Potter
# 	T90 T91 spielen
# 	T91 T92 zu
# 	T92 T93 können
# 	T93 T94 ,
# 	T94 T95 muss
# 	T95 T96 er
# 	T96 T97 sich
# 	T97 T98 verpflichten
# 	T98 T99 ,
# 	T99 T100 die
# 	T100 T101 Kopie
# 	T101 T102 an
# 	T102 T103 sieben
# 	T103 T104 Tagen
# 	T104 T105 dreimal
# 	T105 T106 hintereinander
# 	T106 T107 zu
# 	T107 T108 zeigen
# 	T108 T109 .
# 	T109 T110 Egal
# 	T110 T111 wie
# 	T111 T112 viele
# 	T112 T113 Zuschauer
# 	T113 T114 kommen
# 	T114 T115 .
# 	T115 T116 Das
# 	T116 T117 hat
# 	T117 T118 viele
# 	T118 T119 Kinobesitzer
# 	T119 T120 empört
# 	T120 T121 .
# 	T121 T122 Wenn
# 	T122 T123 sie
# 	T123 T124 jetzt
# 	T124 T125 wieder
# 	T125 T126 einen
# 	T126 T127 Knebelvertrag
# 	T127 T128 beim
# 	T128 T129 "
# 	T129 T130 Herrn
# 	T130 T131 der
# 	T131 T132 Ringe
# 	T132 T133 "
# 	T133 T134 unterschreiben
# 	T134 T135 sollen
# 	T135 T136 ,
# 	T136 T137 erwägt
# 	T137 T138 so
# 	T138 T139 mancher
# 	T139 T140 ,
# 	T140 T141 sich
# 	T141 T142 dem
# 	T142 T143 einfach
# 	T143 T144 zu
# 	T144 T145 verweigern
# 	T145 T146 .
# 	T146 T147 Außerdem
# 	T147 T148 wird
# 	T148 T149 man
# 	T149 T150 sich
# 	T150 T151 nicht
# 	T151 T152 nur
# 	T152 T153 in
# 	T153 T154 katholischen
# 	T154 T155 Gegenden
# 	T155 T156 kaum
# 	T156 T157 zwingen
# 	T157 T158 lassen
# 	T158 T159 ,
# 	T159 T160 Heiligabend
# 	T160 T161 und
# 	T161 T162 Silvester
# 	T162 T163 das
# 	T163 T164 Fantasiespektakel
# 	T164 T165 abzuspielen
# 	T165 T166 .
# 	T166 T167 Der
# 	T167 T168 Verleih
# 	T168 T169 Warner
# 	T169 T170 Bros
# 	T170 T171 muss
# 	T171 T172 sich
# 	T172 T173 schon
# 	T173 T174 etwas
# 	T174 T175 anderes
# 	T175 T176 einfallen
# 	T176 T177 lassen
# 	T177 T178 .
# TIE1 pos t [tiger:pos]
# 	T0 T1 NN
# 	T1 T2 ADV
# 	T2 T3 VMFIN
# 	T3 T4 PPER
# 	T4 T5 PPER
# 	T5 T6 PTKNEG
# 	T6 T7 ADV
# 	T7 T8 VVINF
# 	T8 T9 $.
# 	T9 T10 NN
# 	T10 T11 $,
# 	T11 T12 TRUNC
# 	T12 T13 NN
# 	T13 T14 $,
# 	T14 T15 ADJA
# 	T15 T16 NN
# 	T16 T17 KON
# 	T17 T18 ADV
# 	T18 T19 ADV
# 	T19 T20 $.
# 	T20 T21 KON
# 	T21 T22 ADV
# 	T22 T23 VVFIN
# 	T23 T24 ADV
# 	T24 T25 ART
# 	T25 T26 ADJA
# 	T26 T27 NN
# 	T27 T28 $.
# 	T28 T29 $(
# 	T29 T30 ART
# 	T30 T31 NN
# 	T31 T32 ART
# 	T32 T33 NN
# 	T33 T34 $(
# 	T34 T35 $.
# 	T35 T36 ADV
# 	T36 T37 APPR
# 	T37 T38 PIAT
# 	T38 T39 ADJA
# 	T39 T40 NN
# 	T40 T41 VVFIN
# 	T41 T42 PRF
# 	T42 T43 ART
# 	T43 T44 NE
# 	T44 T45 KON
# 	T45 T46 ART
# 	T46 T47 NN
# 	T47 T48 $.
# 	T48 T49 ADV
# 	T49 T50 VVFIN
# 	T50 T51 ART
# 	T51 T52 NN
# 	T52 T53 ADJD
# 	T53 T54 $,
# 	T54 T55 VMFIN
# 	T55 T56 PIS
# 	T56 T57 ADV
# 	T57 T58 VVINF
# 	T58 T59 KON
# 	T59 T60 ART
# 	T60 T61 ADJA
# 	T61 T62 NN
# 	T62 T63 VVFIN
# 	T63 T64 ADV
# 	T64 T65 ADV
# 	T65 T66 ART
# 	T66 T67 ADJA
# 	T67 T68 NN
# 	T68 T69 PTKVZ
# 	T69 T70 $.
# 	T70 T71 KON
# 	T71 T72 PWS
# 	T72 T73 VVFIN
# 	T73 T74 ART
# 	T74 T75 NN
# 	T75 T76 APPR
# 	T76 T77 ART
# 	T77 T78 NN
# 	T78 T79 $,
# 	T79 T80 PRELS
# 	T80 T81 ADV
# 	T81 T82 ADV
# 	T82 T83 PPOSAT
# 	T83 T84 NN
# 	T84 T85 VVINF
# 	T85 T86 VMFIN
# 	T86 T87 $.
# 	T87 T88 KOUI
# 	T88 T89 NE
# 	T89 T90 NE
# 	T90 T91 VVINF
# 	T91 T92 PTKZU
# 	T92 T93 VMINF
# 	T93 T94 $,
# 	T94 T95 VMFIN
# 	T95 T96 PPER
# 	T96 T97 PRF
# 	T97 T98 VVINF
# 	T98 T99 $,
# 	T99 T100 ART
# 	T100 T101 NN
# 	T101 T102 APPR
# 	T102 T103 CARD
# 	T103 T104 NN
# 	T104 T105 ADV
# 	T105 T106 ADV
# 	T106 T107 PTKZU
# 	T107 T108 VVINF
# 	T108 T109 $.
# 	T109 T110 ADJD
# 	T110 T111 PWAV
# 	T111 T112 PIAT
# 	T112 T113 NN
# 	T113 T114 VVFIN
# 	T114 T115 $.
# 	T115 T116 PDS
# 	T116 T117 VAFIN
# 	T117 T118 PIAT
# 	T118 T119 NN
# 	T119 T120 VVPP
# 	T120 T121 $.
# 	T121 T122 KOUS
# 	T122 T123 PPER
# 	T123 T124 ADV
# 	T124 T125 ADV
# 	T125 T126 ART
# 	T126 T127 NN
# 	T127 T128 APPRART
# 	T128 T129 $(
# 	T129 T130 NN
# 	T130 T131 ART
# 	T131 T132 NN
# 	T132 T133 $(
# 	T133 T134 VVINF
# 	T134 T135 VMFIN
# 	T135 T136 $,
# 	T136 T137 VVFIN
# 	T137 T138 ADV
# 	T138 T139 PIS
# 	T139 T140 $,
# 	T140 T141 PRF
# 	T141 T142 PDS
# 	T142 T143 ADV
# 	T143 T144 PTKZU
# 	T144 T145 VVINF
# 	T145 T146 $.
# 	T146 T147 PROAV
# 	T147 T148 VAFIN
# 	T148 T149 PIS
# 	T149 T150 PRF
# 	T150 T151 PTKNEG
# 	T151 T152 ADV
# 	T152 T153 APPR
# 	T153 T154 ADJA
# 	T154 T155 NN
# 	T155 T156 ADV
# 	T156 T157 VVINF
# 	T157 T158 VVINF
# 	T158 T159 $,
# 	T159 T160 NN
# 	T160 T161 KON
# 	T161 T162 NN
# 	T162 T163 ART
# 	T163 T164 NN
# 	T164 T165 VVIZU
# 	T165 T166 $.
# 	T166 T167 ART
# 	T167 T168 NN
# 	T168 T169 NE
# 	T169 T170 NE
# 	T170 T171 VMFIN
# 	T171 T172 PRF
# 	T172 T173 ADV
# 	T173 T174 PIAT
# 	T174 T175 PIS
# 	T175 T176 VVINF
# 	T176 T177 VVINF
# 	T177 T178 $.
# TIE2 syntax t [tiger:syntax]
# 	T4 T19 VP
# 	T24 T33 NP
# 	T35 T40 PP
# 	T42 T47 CNP
# 	T48 T58 S
# 	T59 T69 S
# 	T73 T86 NP
# 	T87 T93 VP
# 	T96 T108 VP
# 	T110 T114 S
# 	T117 T120 VP
# 	T121 T135 S
# 	T137 T139 NP
# 	T140 T145 VP
# 	T146 T165 VP
# 	T166 T170 NP
# 	T171 T177 VP
# TIE4 syntax t [tiger:syntax]
# 	T4 T19 NP
# 	T29 T33 PN
# 	T42 T44 NP
# 	T45 T47 NP
# 	T48 T58 VP
# 	T59 T62 NP
# 	T65 T68 NP
# 	T75 T78 PP
# 	T80 T82 AVP
# 	T82 T84 NP
# 	T88 T90 PN
# 	T91 T93 VZ
# 	T99 T101 NP
# 	T101 T104 PP
# 	T104 T106 AVP
# 	T106 T108 VZ
# 	T110 T113 NP
# 	T117 T119 NP
# 	T125 T127 NP
# 	T129 T132 NP
# 	T143 T145 VZ
# 	T150 T152 AVP
# 	T159 T162 CNP
# 	T162 T164 NP
# 	T168 T170 PN
# 	T171 T176 VP
# TIE5 syntax t [tiger:syntax]
# 	T5 T7 AVP
# 	T9 T19 CO
# 	T29 T33 NP
# 	T48 T53 S
# 	T79 T86 S
# 	T88 T91 VP
# 	T99 T108 VP
# 	T110 T112 AP
# 	T125 T134 VP
# 	T149 T165 VP
# 	T173 T175 NP
# TIE6 syntax t [tiger:syntax]
# 	T11 T13 NP
# 	T14 T16 NP
# 	T17 T19 AVP
# 	T31 T33 NP
# 	T50 T52 NP
# 	T82 T85 VP
# 	T127 T132 PP
# 	T150 T155 PP
# 	T159 T165 VP
# TIE7 syntax t [tiger:syntax]
# 	T129 T132 PN
# TIE8 syntax t [tiger:syntax]
# 	T130 T132 NP
# TIE3 sentence t [tiger:sentence]
# 	T0 T1 None
# 	T1 T20 None
# 	T20 T35 None
# 	T35 T48 None
# 	T48 T70 None
# 	T70 T87 None
# 	T87 T109 None
# 	T109 T115 None
# 	T115 T121 None
# 	T121 T146 None
# 	T146 T166 None
# 	T166 T178 None
# TIE9 sentence t [tiger:sentence]
# 	T1 T19 S
# 	T20 T33 S
# 	T35 T47 S
# 	T48 T69 CS
# 	T70 T86 S
# 	T87 T108 S
# 	T109 T114 S
# 	T115 T120 S
# 	T121 T145 S
# 	T146 T165 S
# 	T166 T177 S
# TIE10 SEGMENT a [SEGMENT]
# 	T0 T1 HSF
# 	T1 T9 HS
# 	T9 T20 FRB
# 	T20 T28 HS
# 	T28 T35 FRB
# 	T35 T48 HS
# 	T48 T70 HS
# 	T70 T87 HS
# 	T87 T109 HS
# 	T109 T115 HSF
# 	T115 T121 HS
# 	T121 T146 HS
# 	T146 T166 HS
# 	T166 T178 HS
# TIE11 SEGMENT-1 a [SEGMENT-1]
# 	T48 T58 HS
# 	T58 T70 HS
# 	T79 T87 ARR
# 	T87 T94 ADV
# 	T99 T109 OBJ
# 	T110 T115 SUB
# 	T121 T136 ADV
# 	T140 T146 OBJ
# 	T159 T166 OBJ
# TIE12 SEGMENT-2 a [SEGMENT-2]
# 	T48 T54 OBJ
