# %% [markdown]
# # Task: add missing sentence-level annotations to Exmaralda files

# %% [markdown]
# AP told me that 20 of the Exmaralda-annotated MAZ176 files don't have a `tiger:sentence` tier.
#
# ```
# $ for i in *.exb ; do grep -cH "category=\"sentence\"" $i ; done | grep "0$"
# maz-00001.exb:0
# maz-00002.exb:0
# maz-1423.exb:0
# maz-1453.exb:0
# maz-1679.exb:0
# maz-1757.exb:0
# maz-1818.exb:0
# maz-2316.exb:0
# maz-2609.exb:0
# maz-2611.exb:0
# maz-2669.exb:0
# maz-3073.exb:0
# maz-3080.exb:0
# maz-3110.exb:0
# maz-3277.exb:0
# maz-3367.exb:0
# maz-3377.exb:0
# maz-3415.exb:0
# maz-3547.exb:0
# maz-4031.exb:0
# ```
#
# The annotations mentioned are present in the Exmaralda files I gave to the annotator:
#
# ```
# $ /tmp/pcc176_tiger2exmaralda $ ack-grep -c "category=\"sentence\"" | cut -d : -f 2 | uniq
# 1
# ```

# %%
import os
import glob

BROKEN_EXMARALDA_DIR = os.path.expanduser('~/repos/pcc-annis-merged/maz176/information-structure/')

# %%
exmaralda_files = glob.glob(os.path.join(BROKEN_EXMARALDA_DIR, '*.exb'))

# %%
EXB_EXAMPLE = exmaralda_files[0]
print EXB_EXAMPLE
# Out:
# /home/arne/repos/pcc-annis-merged/maz176/information-structure/maz-14071.exb

# %%
from lxml import etree

# %%
tree = etree.parse(EXB_EXAMPLE)

# %%
ct = tree.find('//common-timeline')

# %%
from operator import itemgetter, attrgetter

tokenid_time_tuples = sorted( [(tli.attrib['id'], float(tli.attrib['time'])) for tli in ct.iterchildren()], key=itemgetter(1))

# %%
# [token_id for (token_id, time) in tokenid_time_tuples]

def get_token_ids(exmaralda_etree):
    def tok2time(token_element):
        '''
        extracts the time (float) of a <tli> element
        (i.e. the absolute position of a token in the document)
        '''
        return float(token_element.attrib['time'])

    timeline = exmaralda_etree.find('//common-timeline')
    return (tok.attrib['id'] for tok in sorted((tli for tli in timeline.iterchildren()), key=tok2time))

# get_token_ids(tree)

# %%
import re
from discoursegraphs import DiscourseDocumentGraph

def tokenid2index(token_id):
    """converts a token ID (e.g. 'T0') to its index (i.e. 0)"""
    return int(token_id[1:])

def indexdelta(stop_id, start_id):
    return tokenid2index(stop_id) - tokenid2index(start_id)

def gen_token_range(start_id, stop_id):
    """
    halboffenes Intervall [start, stop)
    
    >>> gen_token_range('T0', 'T1')
    ['T0']
    
    >>> gen_token_range('T1', 'T5')
    ['T1', 'T2', 'T3', 'T4']
    """
    index_range = range(tokenid2index(start_id), tokenid2index(stop_id))
    return ["T{}".format(index) for index in index_range]

# %%
gen_token_range('T1', 'T5')
# Out:
# ['T1', 'T2', 'T3', 'T4']

# %%
from discoursegraphs import EdgeTypes

class ExmaraldaDocumentGraph(DiscourseDocumentGraph):
    def __init__(self, exmaralda_file, name=None, namespace='exmaralda', token_tier='tok'):
        # super calls __init__() of base class DiscourseDocumentGraph
        super(ExmaraldaDocumentGraph, self).__init__()
        self.name = name
        self.ns = namespace
        
        tree = etree.parse(exmaralda_file)
        self.tokens = []
        
        self.__add_tokenization()
        
        for tier in tree.iter('tier'):
            self.__add_tier(tier, token_tier_name=token_tier)
    
    def __add_tokenization(self):
        """adds a node for each token ID in the document"""
        for token_id in get_token_ids(tree):
            self.add_node(token_id, layers={self.ns})
            self.tokens.append(token_id)
    
    def __add_tier(self, tier, token_tier_name):
        tier_id = tier.attrib['id']
        tier_category = tier.attrib['category']
        if tier_category == token_tier_name:
            for event in tier.iter('event'):
                assert indexdelta(event.attrib['end'], event.attrib['start']) == 1, \
                    "Events in the token tier must not span more than one token."
                token_id = event.attrib['start']
                self.node[token_id][self.ns+':token'] = event.text
        else:
            for i, event in enumerate(tier.iter('event')):
                span_id = '{}_{}'.format(tier_id, i)
                span_tokens = gen_token_range(event.attrib['start'], event.attrib['end'])
                self.add_node(span_id, layers={self.ns, self.ns+':span'},
                              edge_type=EdgeTypes.spanning_relation,
                              attr_dict={self.ns+':annotation': event.text,
                                         'label': event.text})
                for token_id in span_tokens:
                    self.add_edge(span_id, token_id, layers={self.ns})

# %%
edg = ExmaraldaDocumentGraph(EXB_EXAMPLE)

# %load_ext gvmagic
from discoursegraphs import print_dot
# Out:
# The gvmagic extension is already loaded. To reload it, use:
#   %reload_ext gvmagic

# %%
# %dotstr print_dot(edg)

# %%
for tier in tree.iter('tier'):
    print tier.attrib['id'], tier.attrib['category'], tier.attrib['type'], tier.attrib['display-name']
    for event in tier.iter('event'):
        print '\t', indexdelta(event.attrib['end'], event.attrib['start']), event.attrib['start'], event.attrib['end'], event.text
# Out:
# TIE0 tok t [tok]
# 	1 T0 T1 Sie
# 	1 T1 T2 bleiben
# 	1 T2 T3 Wittstocker
# 	1 T3 T4 Die
# 	1 T4 T5 Haushaltsdiskussion
# 	1 T5 T6 in
# 	1 T6 T7 Wittstock
# 	1 T7 T8 ist
# 	1 T8 T9 in
# 	1 T9 T10 vollem
# 	1 T10 T11 Gange
# 	1 T11 T12 .
# 	1 T12 T13 Derzeit
# 	1 T13 T14 will
# 	1 T14 T15 jeder
# 	1 T15 T16 Fachausschuss
# 	1 T16 T17 die
# 	1 T17 T18 eigenen
# 	1 T18 T19 finanziellen
# 	1 T19 T20 Interessen
# 	1 T20 T21 sichern
# 	1 T21 T22 -
# 	1 T22 T23 zum
# 	1 T23 T24 Beispiel
# 	1 T24 T25 Eigenmittel
# 	1 T25 T26 für
# 	1 T26 T27 Investitionen
# 	1 T27 T28 oder
# 	1 T28 T29 Zuschüsse
# 	1 T29 T30 für
# 	1 T30 T31 Betriebs-
# 	1 T31 T32 und
# 	1 T32 T33 Unterhaltskosten
# 	1 T33 T34 von
# 	1 T34 T35 Einrichtungen
# 	1 T35 T36 freier
# 	1 T36 T37 Träger
# 	1 T37 T38 .
# 	1 T38 T39 Andererseits
# 	1 T39 T40 muss
# 	1 T40 T41 der
# 	1 T41 T42 Haushalt
# 	1 T42 T43 ausgeglichen
# 	1 T43 T44 sein
# 	1 T44 T45 .
# 	1 T45 T46 Ohne
# 	1 T46 T47 Rotstift
# 	1 T47 T48 wird
# 	1 T48 T49 wohl
# 	1 T49 T50 die
# 	1 T50 T51 Rechnerei
# 	1 T51 T52 nicht
# 	1 T52 T53 aufgehen
# 	1 T53 T54 .
# 	1 T54 T55 Kein
# 	1 T55 T56 Wunder
# 	1 T56 T57 also
# 	1 T57 T58 ,
# 	1 T58 T59 dass
# 	1 T59 T60 jetzt
# 	1 T60 T61 jeder
# 	1 T61 T62 einzelne
# 	1 T62 T63 Haushaltsposten
# 	1 T63 T64 auf
# 	1 T64 T65 den
# 	1 T65 T66 Prüfstand
# 	1 T66 T67 kommt
# 	1 T67 T68 .
# 	1 T68 T69 Auch
# 	1 T69 T70 für
# 	1 T70 T71 das
# 	1 T71 T72 kaum
# 	1 T72 T73 öffentlich
# 	1 T73 T74 gemachte
# 	1 T74 T75 Thema
# 	1 T75 T76 der
# 	1 T76 T77 Sozialfürsorgepflicht
# 	1 T77 T78 der
# 	1 T78 T79 Kommune
# 	1 T79 T80 kann
# 	1 T80 T81 keine
# 	1 T81 T82 Schranke
# 	1 T82 T83 gelten
# 	1 T83 T84 .
# 	1 T84 T85 Vom
# 	1 T85 T86 eigenen
# 	1 T86 T87 Obdachlosenheim
# 	1 T87 T88 hat
# 	1 T88 T89 sich
# 	1 T89 T90 die
# 	1 T90 T91 Stadt
# 	1 T91 T92 vor
# 	1 T92 T93 über
# 	1 T93 T94 einem
# 	1 T94 T95 Jahr
# 	1 T95 T96 getrennt
# 	1 T96 T97 .
# 	1 T97 T98 Die
# 	1 T98 T99 obdachlosen
# 	1 T99 T100 Wittstocker
# 	1 T100 T101 kamen
# 	1 T101 T102 nach
# 	1 T102 T103 Heinrichsfelde
# 	1 T103 T104 und
# 	1 T104 T105 müssen
# 	1 T105 T106 demnächst
# 	1 T106 T107 nach
# 	1 T107 T108 Kyritz
# 	1 T108 T109 ziehen
# 	1 T109 T110 .
# 	1 T110 T111 Geld
# 	1 T111 T112 an
# 	1 T112 T113 den
# 	1 T113 T114 Betreiber
# 	1 T114 T115 der
# 	1 T115 T116 Unterkünfte
# 	1 T116 T117 zu
# 	1 T117 T118 zahlen
# 	1 T118 T119 ,
# 	1 T119 T120 ist
# 	1 T120 T121 für
# 	1 T121 T122 die
# 	1 T122 T123 Stadt
# 	1 T123 T124 billiger
# 	1 T124 T125 .
# 	1 T125 T126 Die
# 	1 T126 T127 soziale
# 	1 T127 T128 Lage
# 	1 T128 T129 der
# 	1 T129 T130 Betroffenen
# 	1 T130 T131 ändert
# 	1 T131 T132 sich
# 	1 T132 T133 bei
# 	1 T133 T134 diesem
# 	1 T134 T135 Rechenbeispiel
# 	1 T135 T136 aber
# 	1 T136 T137 nicht
# 	1 T137 T138 .
# 	1 T138 T139 Die
# 	1 T139 T140 moralische
# 	1 T140 T141 Verantwortung
# 	1 T141 T142 bleibt
# 	1 T142 T143 außen
# 	1 T143 T144 vor
# 	1 T144 T145 .
# 	1 T145 T146 Die
# 	1 T146 T147 Frage
# 	1 T147 T148 stellt
# 	1 T148 T149 sich
# 	1 T149 T150 ,
# 	1 T150 T151 ob
# 	1 T151 T152 nicht
# 	1 T152 T153 die
# 	1 T153 T154 Randgruppe
# 	1 T154 T155 der
# 	1 T155 T156 Obdachlosen
# 	1 T156 T157 auch
# 	1 T157 T158 mit
# 	1 T158 T159 dem
# 	1 T159 T160 neuen
# 	1 T160 T161 Quartier
# 	1 T161 T162 in
# 	1 T162 T163 Kyritz
# 	1 T163 T164 weiter
# 	1 T164 T165 auf
# 	1 T165 T166 das
# 	1 T166 T167 Abstellgleich
# 	1 T167 T168 geschoben
# 	1 T168 T169 werden
# 	1 T169 T170 .
# 	1 T170 T171 Denn
# 	1 T171 T172 eigentlich
# 	1 T172 T173 sind
# 	1 T173 T174 sie
# 	1 T174 T175 ja
# 	1 T175 T176 in
# 	1 T176 T177 Wittstock
# 	1 T177 T178 zu
# 	1 T178 T179 Hause
# 	1 T179 T180 .
# TIE1 pos t [tiger:pos]
# 	1 T0 T1 PPER
# 	1 T1 T2 VVFIN
# 	1 T2 T3 NN
# 	1 T3 T4 ART
# 	1 T4 T5 NN
# 	1 T5 T6 APPR
# 	1 T6 T7 NE
# 	1 T7 T8 VAFIN
# 	1 T8 T9 APPR
# 	1 T9 T10 ADJA
# 	1 T10 T11 NN
# 	1 T11 T12 $.
# 	1 T12 T13 ADV
# 	1 T13 T14 VMFIN
# 	1 T14 T15 PIAT
# 	1 T15 T16 NN
# 	1 T16 T17 ART
# 	1 T17 T18 ADJA
# 	1 T18 T19 ADJA
# 	1 T19 T20 NN
# 	1 T20 T21 VVINF
# 	1 T21 T22 $(
# 	1 T22 T23 APPRART
# 	1 T23 T24 NN
# 	1 T24 T25 NN
# 	1 T25 T26 APPR
# 	1 T26 T27 NN
# 	1 T27 T28 KON
# 	1 T28 T29 NN
# 	1 T29 T30 APPR
# 	1 T30 T31 TRUNC
# 	1 T31 T32 KON
# 	1 T32 T33 NN
# 	1 T33 T34 APPR
# 	1 T34 T35 NN
# 	1 T35 T36 ADJA
# 	1 T36 T37 NN
# 	1 T37 T38 $.
# 	1 T38 T39 ADV
# 	1 T39 T40 VMFIN
# 	1 T40 T41 ART
# 	1 T41 T42 NN
# 	1 T42 T43 VVPP
# 	1 T43 T44 VAINF
# 	1 T44 T45 $.
# 	1 T45 T46 APPR
# 	1 T46 T47 NN
# 	1 T47 T48 VAFIN
# 	1 T48 T49 ADV
# 	1 T49 T50 ART
# 	1 T50 T51 NN
# 	1 T51 T52 PTKNEG
# 	1 T52 T53 VVINF
# 	1 T53 T54 $.
# 	1 T54 T55 PIAT
# 	1 T55 T56 NN
# 	1 T56 T57 ADV
# 	1 T57 T58 $,
# 	1 T58 T59 KOUS
# 	1 T59 T60 ADV
# 	1 T60 T61 PIAT
# 	1 T61 T62 ADJA
# 	1 T62 T63 NN
# 	1 T63 T64 APPR
# 	1 T64 T65 ART
# 	1 T65 T66 NN
# 	1 T66 T67 VVFIN
# 	1 T67 T68 $.
# 	1 T68 T69 ADV
# 	1 T69 T70 APPR
# 	1 T70 T71 ART
# 	1 T71 T72 ADV
# 	1 T72 T73 ADJD
# 	1 T73 T74 ADJA
# 	1 T74 T75 NN
# 	1 T75 T76 ART
# 	1 T76 T77 NN
# 	1 T77 T78 ART
# 	1 T78 T79 NN
# 	1 T79 T80 VMFIN
# 	1 T80 T81 PIAT
# 	1 T81 T82 NN
# 	1 T82 T83 VVINF
# 	1 T83 T84 $.
# 	1 T84 T85 APPRART
# 	1 T85 T86 ADJA
# 	1 T86 T87 NN
# 	1 T87 T88 VAFIN
# 	1 T88 T89 PRF
# 	1 T89 T90 ART
# 	1 T90 T91 NN
# 	1 T91 T92 APPR
# 	1 T92 T93 ADV
# 	1 T93 T94 ART
# 	1 T94 T95 NN
# 	1 T95 T96 VVPP
# 	1 T96 T97 $.
# 	1 T97 T98 ART
# 	1 T98 T99 ADJA
# 	1 T99 T100 NN
# 	1 T100 T101 VVFIN
# 	1 T101 T102 APPR
# 	1 T102 T103 NE
# 	1 T103 T104 KON
# 	1 T104 T105 VMFIN
# 	1 T105 T106 ADV
# 	1 T106 T107 APPR
# 	1 T107 T108 NE
# 	1 T108 T109 VVINF
# 	1 T109 T110 $.
# 	1 T110 T111 NN
# 	1 T111 T112 APPR
# 	1 T112 T113 ART
# 	1 T113 T114 NN
# 	1 T114 T115 ART
# 	1 T115 T116 NN
# 	1 T116 T117 PTKZU
# 	1 T117 T118 VVINF
# 	1 T118 T119 $,
# 	1 T119 T120 VAFIN
# 	1 T120 T121 APPR
# 	1 T121 T122 ART
# 	1 T122 T123 NN
# 	1 T123 T124 ADJD
# 	1 T124 T125 $.
# 	1 T125 T126 ART
# 	1 T126 T127 ADJA
# 	1 T127 T128 NN
# 	1 T128 T129 ART
# 	1 T129 T130 NN
# 	1 T130 T131 VVFIN
# 	1 T131 T132 PRF
# 	1 T132 T133 APPR
# 	1 T133 T134 PDAT
# 	1 T134 T135 NN
# 	1 T135 T136 ADV
# 	1 T136 T137 PTKNEG
# 	1 T137 T138 $.
# 	1 T138 T139 ART
# 	1 T139 T140 ADJA
# 	1 T140 T141 NN
# 	1 T141 T142 VVFIN
# 	1 T142 T143 ADV
# 	1 T143 T144 ADV
# 	1 T144 T145 $.
# 	1 T145 T146 ART
# 	1 T146 T147 NN
# 	1 T147 T148 VVFIN
# 	1 T148 T149 PRF
# 	1 T149 T150 $,
# 	1 T150 T151 KOUS
# 	1 T151 T152 PTKNEG
# 	1 T152 T153 ART
# 	1 T153 T154 NN
# 	1 T154 T155 ART
# 	1 T155 T156 NN
# 	1 T156 T157 ADV
# 	1 T157 T158 APPR
# 	1 T158 T159 ART
# 	1 T159 T160 ADJA
# 	1 T160 T161 NN
# 	1 T161 T162 APPR
# 	1 T162 T163 NE
# 	1 T163 T164 ADV
# 	1 T164 T165 APPR
# 	1 T165 T166 ART
# 	1 T166 T167 NN
# 	1 T167 T168 VVPP
# 	1 T168 T169 VAFIN
# 	1 T169 T170 $.
# 	1 T170 T171 KON
# 	1 T171 T172 ADV
# 	1 T172 T173 VAFIN
# 	1 T173 T174 PPER
# 	1 T174 T175 ADV
# 	1 T175 T176 APPR
# 	1 T176 T177 NE
# 	1 T177 T178 APPR
# 	1 T178 T179 NN
# 	1 T179 T180 $.
# TIE2 comment t [tiger:comment]
# 	1 T166 T167 orig: "Abstellgleich"
# TIE3 syntax t [tiger:syntax]
# 	4 T3 T7 NP
# 	3 T8 T11 PP
# 	2 T14 T16 NP
# 	21 T16 T37 VP
# 	2 T40 T42 NP
# 	2 T42 T44 VP
# 	8 T45 T53 VP
# 	2 T54 T56 NP
# 	9 T58 T67 S
# 	15 T68 T83 VP
# 	12 T84 T96 VP
# 	6 T97 T103 S
# 	3 T106 T109 VP
# 	8 T110 T118 VP
# 	3 T120 T123 PP
# 	5 T125 T130 NP
# 	3 T132 T135 PP
# 	3 T138 T141 NP
# 	2 T142 T144 AVP
# 	24 T145 T169 NP
# 	2 T175 T177 PP
# 	2 T177 T179 PP
# TIE5 syntax t [tiger:syntax]
# 	2 T5 T7 PP
# 	21 T16 T37 NP
# 	2 T45 T47 PP
# 	2 T49 T51 NP
# 	3 T60 T63 NP
# 	3 T63 T66 PP
# 	11 T68 T79 PP
# 	2 T80 T82 NP
# 	3 T84 T87 PP
# 	2 T89 T91 NP
# 	4 T91 T95 PP
# 	3 T97 T100 NP
# 	2 T101 T103 PP
# 	2 T106 T108 PP
# 	5 T111 T116 PP
# 	2 T116 T118 VZ
# 	2 T128 T130 NP
# 	19 T150 T169 S
# TIE6 syntax t [tiger:syntax]
# 	2 T22 T24 PP
# 	3 T24 T27 NP
# 	9 T28 T37 NP
# 	3 T71 T74 AP
# 	4 T75 T79 NP
# 	2 T92 T94 AP
# 	2 T114 T116 NP
# 	17 T151 T168 VP
# TIE7 syntax t [tiger:syntax]
# 	15 T22 T37 NP
# 	2 T77 T79 NP
# 	4 T152 T156 NP
# 	7 T156 T163 PP
# 	3 T164 T167 PP
# TIE8 syntax t [tiger:syntax]
# 	13 T24 T37 CNP
# 	2 T154 T156 NP
# 	2 T161 T163 PP
# TIE9 syntax t [tiger:syntax]
# 	2 T25 T27 PP
# 	8 T29 T37 PP
# TIE10 syntax t [tiger:syntax]
# 	3 T30 T33 CNP
# 	4 T33 T37 PP
# TIE11 syntax t [tiger:syntax]
# 	2 T35 T37 NP
# TIE4 sentence t [tiger:sentence]
# 	3 T0 T3 None
# 	9 T3 T12 None
# 	26 T12 T38 None
# 	7 T38 T45 None
# 	9 T45 T54 None
# 	14 T54 T68 None
# 	16 T68 T84 None
# 	13 T84 T97 None
# 	13 T97 T110 None
# 	15 T110 T125 None
# 	13 T125 T138 None
# 	7 T138 T145 None
# 	25 T145 T170 None
# 	10 T170 T180 None
# TIE12 sentence t [tiger:sentence]
# 	3 T0 T3 S
# 	8 T3 T11 S
# 	25 T12 T37 S
# 	6 T38 T44 S
# 	8 T45 T53 S
# 	13 T54 T67 S
# 	15 T68 T83 S
# 	12 T84 T96 S
# 	12 T97 T109 CS
# 	14 T110 T124 S
# 	12 T125 T137 S
# 	6 T138 T144 S
# 	24 T145 T169 S
# 	9 T170 T179 S
# TIE13 SEGMENT a [SEGMENT]
# 	3 T0 T3 HS
# 	9 T3 T12 HS
# 	26 T12 T38 HS
# 	7 T38 T45 HS
# 	9 T45 T54 HS
# 	14 T54 T68 HSF
# 	16 T68 T84 HS
# 	13 T84 T97 HS
# 	13 T97 T110 HS
# 	15 T110 T125 HS
# 	13 T125 T138 HS
# 	7 T138 T145 HS
# 	25 T145 T170 HS
# 	10 T170 T180 HS
# TIE14 SEGMENT-1 a [SEGMENT-1]
# 	10 T58 T68 SUB
# 	6 T97 T103 HS
# 	7 T103 T110 HSF
# 	9 T110 T119 SUB
# 	20 T150 T170 ATT
