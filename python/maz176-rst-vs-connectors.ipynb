# %%
# %matplotlib inline

# %install_ext https://raw.github.com/cjdrake/ipython-magic/master/gvmagic.py
# %load_ext gvmagic

import os
from collections import Counter
from operator import itemgetter

import networkx

# import pandas as pd
# from networkx import Graph
# from networkx.algorithms.components.connected import connected_components

from discoursegraphs import select_nodes_by_layer

from discoursegraphs import info, print_dot
from discoursegraphs.readwrite import ConanoDocumentGraph, RSTGraph

DOC_ID = 'maz-2316'
MAZ_ROOTDIR = os.path.expanduser('~/corpora/potsdam-commentary-corpus-2.0.0/')
CONANO_TESTFILE = os.path.join(MAZ_ROOTDIR, 'connectors/{}.xml'.format(DOC_ID))
RST_TESTFILE = os.path.join(MAZ_ROOTDIR, 'rst/{}.rs3'.format(DOC_ID))
# Out:
# The gvmagic extension is already loaded. To reload it, use:
#   %reload_ext gvmagic

# %%
cdg = ConanoDocumentGraph(CONANO_TESTFILE)

# %%
rdg = RSTGraph(RST_TESTFILE)

# %%
cdg.merge_graphs(rdg)
merged_graph = cdg # you don't need to do this; new variable is only introduced for convenience

# %%
# %dotstr print_dot(rdg)

# %%
rdg_reduced = RSTGraph(RST_TESTFILE, tokenize=False)
# %dotstr print_dot(rdg_reduced)

# %%
info(rdg_reduced)
# Out:
# Name: maz-2316.rs3
# Type: RSTGraph
# Number of nodes: 24
# Number of edges: 22
# Average in degree:   0.9167
# Average out degree:   0.9167
#
# Node statistics
# ===============
#
# number of nodes with layers
# 	rst - 24
# 	rst:segment - 13
# 	rst:group - 12
# 	rst:root - 1
#
# number of nodes with attributes
# 	layers - 24
# 	label - 24
# 	rst:text - 13
# 	rst:reltype - 11
#
# Edge statistics
# ===============
#
# number of edges with layers
# 	rst - 22
# 	rst:relation - 22
#
# number of edges with attributes
# 	layers - 22
# 	rst:relname - 22
# 	edge_type - 22
# 	label - 22
#
# most common source edges
# 	13 - 3
# 	15 - 2
# 	20 - 2
# 	22 - 2
# 	24 - 2
#
# most common target edges
# 	2 - 2
# 	3 - 2
# 	5 - 2
# 	9 - 2
# 	10 - 2

# %%
for node_id, node_attrs in rdg_reduced.nodes_iter(data=True):
    if 'rst:reltype' in node_attrs:
        print node_id, node_attrs
# Out:
# 13 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'multinuc', 'label': 'rst:group:multinuc:13'}
# 14 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:14'}
# 15 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:15'}
# 16 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:16'}
# 17 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:17'}
# 18 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:18'}
# 19 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:19'}
# 20 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:20'}
# 21 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:21'}
# 22 {'layers': set(['rst', 'rst:group', 'rst:root']), 'rst:reltype': 'multinuc', 'label': 'rst:root:22'}
# 24 {'layers': set(['rst', 'rst:group']), 'rst:reltype': 'span', 'label': 'rst:group:span:24'}

# %%
rdg_reduced.node[19]
# Out:
# {'label': 'rst:group:span:19',
#  'layers': {'rst', 'rst:group'},
#  'rst:reltype': 'span'}

# %%
print "in: ", rdg_reduced.in_edges(2)
print "in: ", rdg_reduced.out_edges(2)
# Out:
# in:  [(24, 2), (19, 2)]
# in:  []

# %%
rdg_reduced.in_edges(19)
# Out:
# [(22, 19)]

# %%
rdg_reduced.out_edges(19)
# Out:
# [(19, 2)]

# %%
# %dotstr print_dot(rdg_reduced)
