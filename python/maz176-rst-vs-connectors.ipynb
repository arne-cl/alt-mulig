# %%
# %matplotlib inline

# %install_ext https://raw.github.com/cjdrake/ipython-magic/master/gvmagic.py
# %load_ext gvmagic

import os
from collections import Counter
from operator import itemgetter

import networkx

# import pandas as pd
# from networkx import Graph
# from networkx.algorithms.components.connected import connected_components

import discoursegraphs as dg
from discoursegraphs import get_span, select_nodes_by_layer

from discoursegraphs import info, print_dot
from discoursegraphs.readwrite import ConanoDocumentGraph, RSTGraph
from discoursegraphs.readwrite.rst import get_rst_relations

DOC_ID = 'maz-2316'
MAZ_ROOTDIR = os.path.expanduser('~/corpora/potsdam-commentary-corpus-2.0.0/')
CONANO_TESTFILE = os.path.join(MAZ_ROOTDIR, 'connectors/{}.xml'.format(DOC_ID))
RST_TESTFILE = os.path.join(MAZ_ROOTDIR, 'rst/{}.rs3'.format(DOC_ID))

# %%
cdg = ConanoDocumentGraph(CONANO_TESTFILE)

# %%
rdg = RSTGraph(RST_TESTFILE)

# %%
rdg.merge_graphs(cdg)
merged_graph = rdg # you don't need to do this; new variable is only introduced for convenience

# %%
# %dotstr print_dot(rdg)

# %%
rdg_reduced = RSTGraph(RST_TESTFILE, tokenize=False)
# %dotstr print_dot(rdg_reduced)

# %%
info(rdg_reduced)
# Out:
# Name: maz-2316.rs3
# Type: RSTGraph
# Number of nodes: 24
# Number of edges: 22
# Average in degree:   0.9167
# Average out degree:   0.9167
#
# Node statistics
# ===============
#
# number of nodes with layers
# 	rst - 24
# 	rst:segment - 13
# 	rst:group - 11
# 	rst:root - 1
#
# number of nodes with attributes
# 	layers - 24
# 	rst:rel_name - 24
# 	label - 24
# 	rst:segment_type - 13
# 	rst:text - 13
# 	rst:group_type - 11
#
# Edge statistics
# ===============
#
# number of edges with layers
# 	rst - 22
# 	rst:relation - 10
#
# number of edges with attributes
# 	layers - 22
# 	edge_type - 22
# 	rst:rel_name - 22
# 	label - 22
# 	rst:rel_type - 10
#
# most common source edges
# 	rst:16 - 2
# 	rst:17 - 2
# 	rst:14 - 2
# 	rst:13 - 2
# 	rst:22 - 2
#
# most common target edges
# 	rst:16 - 1
# 	rst:17 - 1
# 	rst:14 - 1
# 	rst:15 - 1
# 	rst:12 - 1

# %%
# %dotstr print_dot(rdg_reduced)

# %%
# %dotstr print_dot(cdg)

# %%
connectives_only = ConanoDocumentGraph(CONANO_TESTFILE)

# %%
info(connectives_only)
# Out:
# Name: maz-2316.xml
# Type: ConanoDocumentGraph
# Number of nodes: 213
# Number of edges: 212
# Average in degree:   0.9953
# Average out degree:   0.9953
#
# Node statistics
# ===============
#
# number of nodes with layers
# 	conano - 213
# 	conano:token - 190
# 	conano:unit - 14
# 	conano:ext - 7
# 	conano:int - 7
# 	conano:connective - 7
#
# number of nodes with attributes
# 	layers - 213
# 	conano:token - 190
#
# Edge statistics
# ===============
#
# number of edges with layers
# 	conano - 212
#
# number of edges with attributes
# 	layers - 212
# 	edge_type - 212
#
# most common source edges
# 	11:ext - 41
# 	1:ext - 31
# 	1:connective - 22
# 	8:connective - 14
# 	11:connective - 12
#
# most common target edges
# 	2:int - 1
# 	11:connective - 1
# 	4:connective - 1
# 	token:149 - 1
# 	token:148 - 1

# %%
# %dotstr print_dot(connectives_only)

# %%
from discoursegraphs import natural_sort_key

for unit_id in sorted(select_nodes_by_layer(connectives_only, 'conano:unit'), key=natural_sort_key):
    print unit_id
    print ' '.join(connectives_only.get_token(tok_id) for tok_id in get_span(connectives_only, unit_id))
# Out:
# 1:ext
# Fast möchte man Andreas Wansing , den Geschäftsführer der Wobra , händeringend bitten , von seinem Plan Abstand zu nehmen , aus dem Bestand der Wobra hinaus Wohnungen zu verkaufen .
# 1:int
# Denn noch heute sind die schmerzlichen Folgen jederzeit in der Stadt präsent , den die unüberlegten Wobra-Verkäufe an die Aubis auslösten .
# 2:ext
# Dass die Aubis letztlich den Berliner Senat stürzte ,
# 2:int
# in Brandenburg aber kein Politiker auch nur eine Spur Verantwortung übernehmen musste -
# 4:ext
# in Brandenburg aber kein Politiker auch nur eine Spur Verantwortung übernehmen musste -
# 4:int
# obwohl Geld verschleudert und Mieter verramscht wurden - ist nur noch eine stadtgeschichtliche Fußnote . Zum Beweis :
# 5:ext
# obwohl Geld verschleudert
# 5:int
# und Mieter verramscht wurden -
# 7:ext
# Die damalige Aufsichtsratschefin Margit Spielmann wird am Samstag - obwohl sie bis heute nicht für ihre Wobra-Arbeit entlastet wurde und Schliesing noch im Vorjahr mit der Möglichkeit einer Klage gegen sie drohte - von der SPD wieder als Brandenburger Bundestagsabgeordnete nominiert .
# 7:int
# obwohl sie bis heute nicht für ihre Wobra-Arbeit entlastet wurde und Schliesing noch im Vorjahr mit der Möglichkeit einer Klage gegen sie drohte - von der SPD wieder als Brandenburger Bundestagsabgeordnete nominiert .
# 8:ext
# obwohl sie bis heute nicht für ihre Wobra-Arbeit entlastet wurde
# 8:int
# und Schliesing noch im Vorjahr mit der Möglichkeit einer Klage gegen sie drohte -
# 11:ext
# Zum einen ist es möglich , dass der Verkauf vernünftig vorbereitet und mit den Mietern abgesprochen ist . Zum anderen musste außer Mietern und Mitarbeitern bei der Wobra noch niemand für die Fehler des Managements und des Aufsichtsrates ernsthaft büßen .
# 11:int
# Deshalb muss sich Wansing auch nicht vor Folgen des Verkaufs fürchten :
