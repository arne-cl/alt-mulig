# %%
rabbit <- read.table("http://www.escet.urjc.es/biodiversos/R/rabbit.txt", header=T, sep="\t")

# %%
head(rabbit)
# Out:
#   year rabbit
# 1 1980     80
# 2 1981     50
# 3 1982     50
# 4 1983     52
# 5 1984     57
# 6 1985     80

# %%
str(rabbit)
# Out:
# 'data.frame':	31 obs. of  2 variables:
#  $ year  : int  1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 ...
#  $ rabbit: int  80 50 50 52 57 80 85 108 100 89 ...

# %%
class(rabbit)
# Out:
# [1] "data.frame"

# %%
rabbit.ts <- ts(data=rabbit$rabbit, start=min(rabbit$year), end=max(rabbit$year))

# %%
plot(rabbit~year, data=rabbit, type="b", pch=19, ylab = "rabbits per hectare")
# Out:
# plot without title
